# %%
import os
import sys
import shutil
import matplotlib.pyplot as plt

# 使用 inline 后端（静态图片，速度快）
# %matplotlib inline

# 或者使用 notebook 后端（交互式，但较慢）
# %matplotlib notebook

# %% [markdown]
# ## 导入模块
#
# 导入所有需要的训练模块

# %%
from linear_models import soft_max_head, soft_max_torch
from multilayer_perceptron import (
    mlp_head, mlp_torch, train_3d_poly, train_linear_poly, 
    train_high_degree_poly, weight_decay_head, weight_decay_torch, 
    dropout_head, dropout_torch, kaggle_house_price
)
from CNN import LeNet_main, AlexNet_main

# %% [markdown]
# ## 准备输出目录
#
# 清空并创建 outputs 目录用于保存结果

# %%
# 清空outputs目录
if os.path.exists('outputs'):
    shutil.rmtree('outputs')
    print("已清空outputs目录")
os.makedirs('outputs', exist_ok=True)
# Out:
# 已清空outputs目录

# %% [markdown]
# ## 运行训练

# %%
# 运行 AlexNet 训练
AlexNet_main()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 # 运行 AlexNet 训练
# ----> 2 AlexNet_main()
#
# File d:\data\my_learning\deep-learning\CNN\AlexNet.py:35, in AlexNet_main()
#      33 def AlexNet_main():
#      34     lr, num_epochs = 0.01, 10
# ---> 35     Train.train_ch6(net, train_iter, test_iter, num_epochs, lr, TryGPU.try_gpu())
#
# File d:\data\my_learning\deep-learning\basic\Train.py:140, in Train.train_ch6(cls, net, train_iter, test_iter, num_epochs, lr, device)
#     138 timer.start()
#     139 optimizer.zero_grad()
# --> 140 X, y = X.to(device), y.to(device)
#     141 y_hat = net(X)
#     142 l = loss(y_hat, y)
#
# KeyboardInterrupt:
